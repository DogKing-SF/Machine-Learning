# %% [markdown]
# 手动实现如下图的代码
# ![c31d1413-4e0b-437f-9800-a3ce10934a14.png](attachment:899737d4-2408-4ab3-ab4e-dd89ca1d8f80.png)

# %%
import numpy as np

x= np.array([200,17])
w1_1 = np.array([1,2])
b1_1 = np.array([-1])
z1_1 = np.dot(w1_1,x)+b1_1
a1_1 = sigmoid(z1_1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 7
#       3 x= np.array([200,17])
#       4 w1_1 = np.array([1,2])
#       5 b1_1 = np.array([-1])
#       6 z1_1 = np.dot(w1_1,x)+b1_1
# ----> 7 a1_1 = sigmoid(z1_1)
#
# NameError: name 'sigmoid' is not defined
